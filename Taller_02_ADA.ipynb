# %% [markdown]
# # Análisis de algoritmos - Ejemplo análisis regresión
# ## Uso de statsmodels para análisis de resultados

# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np

# %% [markdown]
# ## Carga de los archivos

# %%
df_results = pd.read_csv('timestamps.res', sep=',', header=None, names=['n','Iterativo', 'Recursivo' ])

# %%
df_results.head()
# Out:
#     n  Iterativo  Recursivo
# 0   5       8542      10292
# 1  10      13750      17583
# 2  15      28542      34292
# 3  20      49917      57375
# 4  25      80375      89500

# %%
df_results.plot(y=['Iterativo','Recursivo'], x='n')
# Out:
# <Axes: xlabel='n'>

# %%
mod = smf.ols('Iterativo ~ np.power(n,2)', data=df_results)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              Iterativo   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                     8860.
# Date:                Sat, 08 Mar 2025   Prob (F-statistic):           1.07e-25
# Time:                        21:29:56   Log-Likelihood:                -221.67
# No. Observations:                  20   AIC:                             447.3
# Df Residuals:                      18   BIC:                             449.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       1.717e+04   5659.840      3.033      0.007    5276.148    2.91e+04
# ...

# %%
res.params
# Out:
# Intercept         17167.031856
# np.power(n, 2)      112.108493
# dtype: float64

# %%
sm.graphics.plot_fit(res,"np.power(n, 2)")

# %% [markdown]
# ### Recursivo

# %%
mod = smf.ols(formula='Recursivo ~ np.power(n,2)', data=df_results)

# %%
res = mod.fit()

# %%
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              Recursivo   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 1.836e+04
# Date:                Sat, 08 Mar 2025   Prob (F-statistic):           1.54e-28
# Time:                        21:31:12   Log-Likelihood:                -215.16
# No. Observations:                  20   AIC:                             434.3
# Df Residuals:                      18   BIC:                             436.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       2.013e+04   4088.182      4.923      0.000    1.15e+04    2.87e+04
# ...

# %%
res.params
# Out:
# Intercept         20125.545706
# np.power(n, 2)      116.574761
# dtype: float64

# %%
sm.graphics.plot_fit(res,"np.power(n, 2)")
